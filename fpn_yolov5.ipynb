# %% [markdown]
# <a href="https://colab.research.google.com/github/toshit11/yolov5-based-on-ultralytics/blob/master/fpn_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import torch
 torch.cuda.empty_cache()

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -r yolov5/requirements.txt  # install dependencies

# %cd yolov5

import torch
from IPython.display import Image, clear_output  # to display im
torch.cuda.empty_cache()
clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.5.1+cu101 CPU

# %%
import zipfile
from google.colab import drive

drive.mount('/content/drive/') # mounting the drive on the google colab
# !ls "/content/drive/My Drive"
# !unzip "/content/drive/My Drive/data.zip" -d "/content/yolov5_traffic_lights/"
# !unzip "/content/drive/My Drive/sample_images.zip" -d "/content/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
#  00013.m2ts
#  00066.mp4
#  1553766661956902838117.jpg
#  298473401.pdf
#  99991596.pdf
#  99991890.pdf
# 'AMU notes 2.pdf'
#  analy
# 'Automatic Lighting & Accident Detection System(Final Report).pdf'
#  CE111.pdf
# 'Certificate '
#  chapter05.pdf
#  classifier.pt
#  Classroom
# 'Colab Notebooks'
#  Cost_Estimation.gsheet
# 'Coursera 2PSKPLYHFY7S (1).pdf'
# 'Coursera 2PSKPLYHFY7S (2).pdf'
# 'Coursera 2PSKPLYHFY7S.pdf'
# 'Coursera AWN49FPZVX3N (1).pdf'
# 'Coursera AWN49FPZVX3N (2).pdf'
# 'Coursera AWN49FPZVX3N.pdf'
# 'Coursera Z9K3HACV4LFM (1).pdf'
# 'Coursera Z9K3HACV4LFM (2).pdf'
# 'Coursera Z9K3HACV4LFM.pdf'
#  data.rar
#  dataset_additional_rgb.zip
#  data.zip
#  didi
# 'expense sheet.gsheet'
#  eye_pattern_1.m
#  gtsrb-german-traffic-sign.zip
#  hackerearth
#  IMG_20170806_110627472.jpg
#  IMG_20170806_110629165.jpg
#  IMG_20170806_110727504.jpg
#  IMG_20170806_110736202.jpg
#  IMG_20170806_110737560.jpg
#  IMG_20170806_110840620.jpg
#  IMG_20170806_110929711.jpg
#  IMG_20170806_110931745.jpg
#  IMG_20170806_110933171.jpg
#  IMG_20170806_110934669.jpg
#  IMG_20170806_111058684_HDR.jpg
#  IMG_20170806_111125025.jpg
#  IMG_20170806_111128723.jpg
#  IMG_20170806_111132052.jpg
#  IMG_20170806_111402725.jpg
#  IMG_20170806_111407215.jpg
#  IMG_20170806_111907824_HDR.jpg
#  IMG_20170806_111939820_HDR.jpg
#  IMG_20170806_124216149.jpg
#  IMG_20170806_124932502_HDR.jpg
#  IMG_20170806_125000647.jpg
#  IMG_20170806_125002485.jpg
#  IMG_20170806_125055969.jpg
#  IMG_20170806_125100063.jpg
#  IMG_20170806_125101770.jpg
#  IMG_20170806_170423744.jpg
#  IMG_20170806_170425868.jpg
#  IMG_20170806_171027636.jpg
#  IMG_20170806_171030570.jpg
#  IMG_20170806_171031984.jpg
#  IMG_20170806_171151908.jpg
#  IMG_20170806_171155235.jpg
#  IMG_20170806_171157221.jpg
#  IMG_20170806_171200075.jpg
#  IMG_20170806_171240237.jpg
#  IMG_20170806_172028628.jpg
#  IMG_20170806_172044879.jpg
#  IMG_20170806_172137473.jpg
#  IMG_20170806_172140322.jpg
#  IMG_20170806_185133020_HDR.jpg
#  IMG_20170806_185150660.jpg
#  IMG_20170806_185337689.jpg
#  IMG_20170806_185423610.jpg
#  IMG_20170806_185427784.jpg
#  IMG_20170806_185816418.jpg
#  IMG_20170806_185818266.jpg
#  IMG_20170806_185828823.jpg
#  IMG_20170806_190040588.jpg
#  IMG_20170807_121709191.jpg
#  IMG_20170807_121711043.jpg
#  IMG_20170807_121713787.jpg
#  IMG_20170807_121812744.jpg
#  IMG_20170807_121824660.jpg
#  IMG_20170807_121826020.jpg
#  IMG_20170807_121841541.jpg
#  IMG_20170807_121849786.jpg
#  IMG_20170807_122656522.jpg
#  IMG_20170807_122704480.jpg
#  IMG_20170807_122724917.jpg
#  IMG_20170807_122728003.jpg
#  IMG_20170807_122730513.jpg
#  IMG_20170807_122733508.jpg
#  IMG_20170807_123215601.jpg
#  IMG_20170807_123217869.jpg
#  IMG_20170807_123222186.jpg
#  IMG_20170807_123224062.jpg
#  IMG_20170807_123323477.jpg
#  IMG_20170807_131148169.jpg
#  IMG_20170807_131330906.jpg
#  IMG_20170807_131332662.jpg
#  IMG_20170807_131334139.jpg
#  IMG_20170807_131827269.jpg
#  IMG_20170807_141832611.jpg
#  IMG_20170807_141917456_HDR.jpg
#  IMG_20170807_143436359.jpg
#  IMG_20170807_144414844.jpg
#  IMG_20170807_150700817.jpg
#  IMG_20170807_152216884.jpg
#  IMG_20170807_152939239.jpg
#  ME101Amunotes.pdf
# 'Membership (1).pdf'
#  mhrd.pdf
# 'minor project'
# 'model (1).h5'
# 'model (2).h5'
#  model.h5
# 'New Doc 2019-03-02.pdf'
#  NLP
# 'Project Networking(R&S).docx'
# 'Project Networking(R&S).gdoc'
# 'RDWA meetings'
#  rebuilt.dataset_test_rgb.zip.001
#  Resume.gdoc
#  sample_images.zip
# 'sir tickit.pdf'
# 't k Rawat.pdf'
# 'toshitcv (1).pdf'
# 'toshitcv (2).pdf'
#  toshitcv.pdf
# 'UC-IB1LRMXF (1).jpg'
# 'UC-IB1LRMXF (2).jpg'
#  UC-IB1LRMXF.jpg
# 'Untitled document.gdoc'
# 'Untitled folder'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'UploadsAshesh Zubair POC Notes.pdf'
# Archive:  /content/drive/My Drive/data.zip
#    creating: /content/yolov5_traffic_lights/data/images/
#    creating: /content/yolov5_traffic_lights/data/images/train/
#   inflating: /content/yolov5_traffic_lights/data/images/train/137042.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/24594.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/24664.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/24734.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/451434.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/453032.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/475396.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/485098.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/492410.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/514516.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/514586.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/535946.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/536016.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/539910.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/558388.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/558456.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/56988.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/57058.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/57128.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/57196.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/57266.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/57336.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/57406.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/575176.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/58576.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/58646.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/591486.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/591556.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/59388.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/59526.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/59666.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/59734.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/59804.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/59874.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/59944.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60012.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60082.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/601426.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/601496.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60152.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60222.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60290.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60360.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60430.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60498.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60568.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60638.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60708.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60776.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60846.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60916.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/60986.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61054.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61124.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61332.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61402.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/614150.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/614496.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/614566.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/614636.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61472.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/614844.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/614914.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/614982.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/615052.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/615192.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61542.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61610.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61680.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61750.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61888.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/619168.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/61958.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/619932.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/620278.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/620348.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/620418.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/620488.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/620766.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/620834.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/620904.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/621252.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/621322.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622044.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622114.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622184.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622254.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622322.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622392.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622462.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622532.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622600.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622670.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622740.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/622948.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/623806.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/624974.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/625044.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/625114.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/625322.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/626182.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/626322.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/626392.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/626460.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/626600.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/626670.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/626738.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/626808.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/627086.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/627224.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/627434.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/627502.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/627572.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/627988.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/629920.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/629988.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/630058.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/630128.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/630544.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/637398.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/643310.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/65286.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/65496.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/65772.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/678126.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/680488.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/680558.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/680626.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/680696.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/680766.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/680974.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/681044.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/681530.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/681876.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/682016.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/682502.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/682572.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/682920.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/683058.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/683266.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/683544.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/683614.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/683684.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/683752.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/683822.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/683892.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/684030.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/684100.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/684794.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/685350.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/685420.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/685490.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/686294.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/686364.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/686434.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/686990.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687058.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687128.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687198.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687268.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687336.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687406.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687544.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687614.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687822.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687892.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/687962.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/688032.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/688100.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/689422.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/689492.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/689562.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/689840.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/689908.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/689978.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/690048.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/690116.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/690186.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/690882.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/692340.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/697962.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/700144.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/96802.png
#   inflating: /content/yolov5_traffic_lights/data/images/train/96870.png
#    creating: /content/yolov5_traffic_lights/data/images/valid/
#   inflating: /content/yolov5_traffic_lights/data/images/valid/700352.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/707012.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/707348.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/707834.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/711516.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/711724.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/713392.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/713460.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/713530.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/713600.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/713670.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/717528.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/717598.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/717668.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/718154.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/718224.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/718500.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/718570.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/718710.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/719266.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/719752.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/719820.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/719890.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/720030.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/720376.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/720446.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/720516.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/720586.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/720724.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/720794.png
#   inflating: /content/yolov5_traffic_lights/data/images/valid/720862.png
#    creating: /content/yolov5_traffic_lights/data/labels/
#    creating: /content/yolov5_traffic_lights/data/labels/train/
#  extracting: /content/yolov5_traffic_lights/data/labels/train/137042.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/24594.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/24664.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/24734.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/451434.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/453032.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/475396.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/485098.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/492410.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/514516.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/514586.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/535946.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/536016.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/539910.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/558388.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/558456.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/56988.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/57058.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/57128.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/57196.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/57266.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/57336.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/57406.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/575176.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/58576.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/58646.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/591486.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/591556.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/59388.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/59526.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/59666.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/59734.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/59804.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/59874.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/59944.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/60012.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60082.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/601426.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/601496.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60152.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60222.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60290.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60360.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/60430.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/60498.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60568.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60638.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60708.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60776.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60846.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60916.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/60986.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/61054.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61124.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61332.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61402.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/614150.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/614496.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/614566.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/614636.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61472.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/614844.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/614914.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/614982.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/615052.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/615192.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61542.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61610.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61680.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61750.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/61888.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/619168.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/61958.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/619932.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/620278.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/620348.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/620418.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/620488.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/620766.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/620834.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/620904.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/621252.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/621322.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/622044.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/622114.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/622184.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/622254.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/622322.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/622392.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/622462.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/622532.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/622600.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/622670.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/622740.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/622948.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/623806.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/624974.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/625044.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/625114.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/625322.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/626182.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/626322.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/626392.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/626460.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/626600.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/626670.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/626738.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/626808.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/627086.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/627224.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/627434.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/627502.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/627572.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/627988.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/629920.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/629988.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/630058.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/630128.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/630544.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/637398.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/643310.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/65286.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/65496.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/65772.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/678126.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/680488.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/680558.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/680626.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/680696.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/680766.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/680974.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/681044.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/681530.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/681876.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/682016.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/682502.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/682572.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/682920.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/683058.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/683266.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/683544.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/683614.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/683684.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/683752.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/683822.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/683892.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/684030.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/684100.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/684794.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/685350.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/685420.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/685490.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/686294.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/686364.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/686434.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/686990.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/687058.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/687128.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/687198.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/687268.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/687336.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/687406.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/687544.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/687614.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/687822.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/687892.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/687962.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/688032.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/688100.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/689422.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/689492.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/689562.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/689840.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/689908.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/689978.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/690048.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/690116.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/690186.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/690882.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/692340.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/697962.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/700144.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/train/96802.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/train/96870.txt
#    creating: /content/yolov5_traffic_lights/data/labels/valid/
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/700352.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/707012.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/707348.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/707834.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/711516.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/711724.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/713392.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/713460.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/713530.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/713600.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/713670.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/717528.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/717598.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/717668.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/718154.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/718224.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/718500.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/718570.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/718710.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/719266.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/719752.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/719820.txt
#  extracting: /content/yolov5_traffic_lights/data/labels/valid/719890.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/720030.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/720376.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/720446.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/720516.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/720586.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/720724.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/720794.txt
#   inflating: /content/yolov5_traffic_lights/data/labels/valid/720862.txt
#   inflating: /content/yolov5_traffic_lights/data/traffic_lights.yaml
#   inflating: /content/yolov5_traffic_lights/data/train.txt
#   inflating: /content/yolov5_traffic_lights/data/val.txt
#   inflating: /content/yolov5_traffic_lights/data/voc.names
# Archive:  /content/drive/My Drive/sample_images.zip
#    creating: /content/sample_images/
#   inflating: /content/sample_images/32008.png
#   inflating: /content/sample_images/471932.png
#   inflating: /content/sample_images/475742.png
#   inflating: /content/sample_images/485168.png
#   inflating: /content/sample_images/545262.png
#   inflating: /content/sample_images/557900.png
#   inflating: /content/sample_images/601420.png
#   inflating: /content/sample_images/620620.png
#   inflating: /content/sample_images/621970.png
#   inflating: /content/sample_images/686558.png
#   inflating: /content/sample_images/701852.png
#   inflating: /content/sample_images/29324.png

# %%
#!mv "/content/train.yaml"  "/content/yolov5/data" # transfering the train yaml file into the yolov5 folder

# %%
import yaml
with open("/content/yolov5_traffic_lights/data/traffic_lights.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])
print(num_classes)
# Out:
# 13

# %%
with open('/content/yolov5/models/custom_yolov5fpn.yaml', 'w') as f:
  f.write('nc: ' + num_classes + '\n')
  #f.write('nc: ' + str(len(class_labels)) + '\n')
  f.write('depth_multiple: 1'  + '\n') # model depth multiple
  f.write('width_multiple: 1'  + '\n')  # layer channel multiple
  f.write('\n')
  f.write('anchors:' + '\n')
  f.write('  - [10,13, 16,30, 33,23] ' + '\n')
  f.write('  - [30,61, 62,45, 59,119]' + '\n')
  f.write('  - [116,90, 156,198, 373,326]' + '\n')
  f.write('\n')

# YOLOv5 backbone
  f.write('backbone:' + '\n')
    # [from, number, module, args]
  f.write(' [[-1, 1, Focus, [64, 3]],'+ '\n')  # 0-P1/2
  f.write('  [-1, 1, Conv, [128, 3, 2]],'+ '\n')  # 1-P2/4
  f.write('  [-1, 3, Bottleneck, [128]],'+ '\n')
  f.write('  [-1, 1, Conv, [256, 3, 2]],'+ '\n')  # 3-P3/8
  f.write('  [-1, 9, BottleneckCSP, [256]],'+ '\n')
  f.write('  [-1, 1, Conv, [512, 3, 2]],'+ '\n')  # 5-P4/16
  f.write('  [-1, 9, BottleneckCSP, [512]],'+ '\n')
  f.write('  [-1, 1, Conv, [1024, 3, 2]],'+ '\n') # 7-P5/32
  f.write('  [-1, 1, SPP, [1024, [5, 9, 13]]],'+ '\n')
  f.write('  [-1, 6, BottleneckCSP, [1024]],'+ '\n')  # 9
  f.write('  ]'+'\n')

# YOLOv5 FPN head
  f.write('head:'+ '\n')
  f.write(' [[-1, 3, BottleneckCSP, [1024, False]],'+ '\n')
  f.write('  [-1, 1, nn.Conv2d, [na * (nc + 5), 1, 1]],'+ '\n')  # 11 (P5/32-large)

  f.write('  [-2, 1, nn.Upsample, [None, 2, "nearest"]],'+ '\n')
  f.write('  [[-1, 6], 1, Concat, [1]],'+ '\n') # cat backbone P4
  f.write('   [-1, 1, Conv, [512, 1, 1]],'+ '\n')
  f.write('   [-1, 3, BottleneckCSP, [512, False]],'+ '\n')
  f.write('  [-1, 1, nn.Conv2d, [na * (nc + 5), 1, 1]],'+ '\n')  # 16 (P4/16-medium)

  f.write('  [-2, 1, nn.Upsample, [None, 2, "nearest"]],'+ '\n')
  f.write('  [[-1, 4], 1, Concat, [1]],'+ '\n')  # cat backbone P3
  f.write('  [-1, 1, Conv, [256, 1, 1]],'+ '\n')
  f.write('  [-1, 3, BottleneckCSP, [256, False]],'+ '\n')
  f.write('  [-1, 1, nn.Conv2d, [na * (nc + 5), 1, 1]],'+ '\n')  # 21 (P3/8-small)

  f.write('  [[], 1, Detect, [nc, anchors]],'+ '\n') # Detect(P3, P4, P5)
  f.write('    ]' + '\n')
print('custom model config written!')
# Out:
# custom model config written!

# %%
# %%time
# %cd /content/yolov5/
# !python train.py --img 640 --batch 16 --epochs 1200 --data '/content/yolov5_traffic_lights/data/traffic_lights.yaml' --cfg ./models/custom_yolov5fpn.yaml --weights '' --name yolov5s_results --nosave --cache # starting the training on bosch dataset for image size of 640
# Out:
# /content/yolov5
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# {'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='./models/custom_yolov5fpn.yaml', data='/content/yolov5_traffic_lights/data/traffic_lights.yaml', device='', epochs=1200, evolve=False, img_size=[640], multi_scale=False, name='yolov5s_results', noautoanchor=False, nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='')
# Using CPU
#
# 2020-07-06 15:47:15.333857: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    246912  models.common.Bottleneck                [128, 128]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1627904  models.common.BottleneckCSP             [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6499840  models.common.BottleneckCSP             [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  1   2624512  models.common.SPP                       [1024, 1024, [5, 9, 13]]
#   9                -1  1  18105344  models.common.BottleneckCSP             [1024, 1024, 6]
#  10                -1  1  10234880  models.common.BottleneckCSP             [1024, 1024, 3, False]
#  11                -1  1     55350  torch.nn.modules.conv.Conv2d            [1024, 54, 1, 1]
#  12                -2  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  13           [-1, 6]  1         0  models.common.Concat                    [1]
#  14                -1  1    787456  models.common.Conv                      [1536, 512, 1, 1]
#  15                -1  1   2561536  models.common.BottleneckCSP             [512, 512, 3, False]
#  16                -1  1     27702  torch.nn.modules.conv.Conv2d            [512, 54, 1, 1]
#  17                -2  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 4]  1         0  models.common.Concat                    [1]
#  19                -1  1    197120  models.common.Conv                      [768, 256, 1, 1]
#  20                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3, False]
#  21                -1  1     13878  torch.nn.modules.conv.Conv2d            [256, 54, 1, 1]
#  22      [-1, 16, 11]  1         0  models.yolo.Detect                      [13, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]]]
# Model Summary: 309 layers, 4.9902e+07 parameters, 4.9902e+07 gradients
#
# Optimizer groups: 102 .bias, 108 conv.weight, 99 other
# Reading image shapes: 100% 184/184 [00:04<00:00, 40.01it/s]
# Caching labels /content/yolov5_traffic_lights/data/train.txt (92 found, 0 missing, 92 empty, 0 duplicate, for 184 images): 100% 184/184 [00:00<00:00, 13485.80it/s]
# Caching images (0.1GB): 100% 184/184 [00:04<00:00, 39.39it/s]
# Reading image shapes: 100% 31/31 [00:00<00:00, 42.01it/s]
# Caching labels /content/yolov5_traffic_lights/data/val.txt (19 found, 0 missing, 12 empty, 0 duplicate, for 31 images): 100% 31/31 [00:00<00:00, 10162.84it/s]
# Caching images (0.0GB): 100% 31/31 [00:00<00:00, 40.97it/s]
#
# Analyzing anchors... Best Possible Recall (BPR) = 0.9157. Attempting to generate improved anchors, please wait...
# WARNING: Extremely small objects found. 54 of 261 labels are < 3 pixels in width or height.
# Running kmeans for 9 anchors on 261 points...
# thr=0.25: 1.0000 best possible recall, 7.41 anchors past thr
# n=9, img_size=640, metric_all=0.498/0.868-mean/best, past_thr=0.568-mean: 3,6,  4,8,  4,12,  5,11,  6,15,  8,18,  10,24,  14,32,  25,57
# Evolving anchors with Genetic Algorithm: fitness = 0.8768: 100% 1000/1000 [00:00<00:00, 2564.05it/s]
# thr=0.25: 1.0000 best possible recall, 7.44 anchors past thr
# n=9, img_size=640, metric_all=0.505/0.877-mean/best, past_thr=0.575-mean: 3,6,  4,8,  4,10,  5,12,  6,15,  8,19,  11,24,  13,30,  26,57
# New anchors saved to model. Update model *.yaml to use these anchors in the future.
#
# Image sizes 640 train, 640 test
# Using 2 dataloader workers
# Starting training for 1200 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#   0% 0/12 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "train.py", line 394, in <module>
#     train(hyp)
#   File "train.py", line 248, in train
#     pred = model(imgs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/yolov5/models/yolo.py", line 96, in forward
#     return self.forward_once(x, profile)  # single-scale inference, train
#   File "/content/yolov5/models/yolo.py", line 116, in forward_once
#     x = m(x)  # run
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/yolov5/models/common.py", line 60, in forward
#     y1 = self.cv3(self.m(self.cv1(x)))
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py", line 353, in forward
#     return self._conv_forward(input, self.weight)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py", line 350, in _conv_forward
#     self.padding, self.dilation, self.groups)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 464) is killed by signal: Killed.
#   0% 0/12 [00:43<?, ?it/s]
# CPU times: user 241 ms, sys: 34.7 ms, total: 276 ms
# Wall time: 1min 6s
